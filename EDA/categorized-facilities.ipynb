# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv("../predicted-facilities2-crnn/predicted_country_hall.csv")
data
# treba izbaciti neke gradove, nights stayed (outlajere), sredeti date da budu samo meseci
# Out:
#       Unnamed: 0   Guest_country                                  Room_info  \
# 0              0   Guest_country                                  Room_info
# 1              1          Kuwait                       Superior Double Room
# 2              2          Kuwait                       Superior Double Room
# 3              3          Kuwait                       Superior Double Room
# 4              4          Kuwait                       Superior Double Room
# ...          ...             ...                                        ...
# 5551        5551  United Kingdom  Superior Double Room with London Eye View
# 5552        5552          Turkey                         Superior Twin Room
# 5553        5553          Turkey                         Superior Twin Room
# 5554        5554          Turkey                         Superior Twin Room
# 5555        5555  United Kingdom  Superior Double Room with London Eye View
#
#       Nights_stayed  Date of stay    Travel_type  \
# 0     Nights_stayed  Date of stay    Travel_type
# 1                 2   August 2018         Family
# 2                 2   August 2018         Family
# 3                 2   August 2018         Family
# 4                 2   August 2018         Family
# ...             ...           ...            ...
# 5551              2     July 2018         Couple
# 5552              1     July 2018  Solo traveler
# 5553              1     July 2018  Solo traveler
# 5554              1     July 2018  Solo traveler
# 5555              1     July 2018         Family
#
#                                                  Review  Grade  \
# 0                                                Review  Grade
# 1      Everything you needed was there: iron, microw...   10.0
# 2      Everything you needed was there: iron, microw...   10.0
# 3      Everything you needed was there: iron, microw...   10.0
# 4      Everything you needed was there: iron, microw...   10.0
# ...                                                 ...    ...
# 5551   Customer service\nLack of care\nIncorrect inf...    2.5
# 5552   It was summer 33 degrees outside but the room...    6.7
# 5553   It was summer 33 degrees outside but the room...    6.7
# 5554   It was summer 33 degrees outside but the room...    6.7
# 5555   Late check in and no compensation for this (r...    6.7
#
#                            Title  Positive   Facilities  Predicted
# 0                          Title  Positive   Facilities          0
# 1     THE place to be in london.         1   food/drink          1
# 2     THE place to be in london.         1     internet          1
# 3     THE place to be in london.         1      comfort          1
# 4     THE place to be in london.         1          bed          1
# ...                          ...       ...          ...        ...
# 5551                   Very poo4         0        staff          0
# 5552                    Pleasant         0     location          0
# 5553                    Pleasant         0          bed          0
# 5554                    Pleasant         0  temperature          0
# 5555                    Pleasant         0        price          0
#
# [5556 rows x 12 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5556 entries, 0 to 5555
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     5556 non-null   int64
#  1   Guest_country  5556 non-null   object
#  2   Room_info      5556 non-null   object
#  3   Nights_stayed  5556 non-null   object
#  4   Date of stay   5556 non-null   object
#  5   Travel_type    5556 non-null   object
#  6   Review         5556 non-null   object
#  7   Grade          5556 non-null   object
#  8   Title          5556 non-null   object
#  9   Positive       5556 non-null   object
#  10  Facilities     5556 non-null   object
#  11  Predicted      5556 non-null   int64
# dtypes: int64(2), object(10)
# memory usage: 521.0+ KB

# %%
data.shape
# Out:
# (5556, 12)

# %%
data.nunique()
# Out:
# Unnamed: 0       5556
# Guest_country      93
# Room_info          14
# Nights_stayed      14
# Date of stay       31
# Travel_type         5
# Review           2457
# Grade              33
# Title             894
# Positive            3
# Facilities         17
# Predicted           2
# dtype: int64

# %%
data.isnull().sum()
# data_poz = data[data['Predicted'] > 0]
# data_neg = data[data['Predicted'] < 1]
# Out:
# Unnamed: 0       0
# Guest_country    0
# Room_info        0
# Nights_stayed    0
# Date of stay     0
# Travel_type      0
# Review           0
# Grade            0
# Title            0
# Positive         0
# Facilities       0
# Predicted        0
# dtype: int64

# %%
# analiza zavisnosti podataka

# %%
corelation = data_poz.corr()
sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.columns, annot=True)

# %%
sns.pairplot(data)

# %%
sns.relplot(x='Grade', y='Nights_stayed', hue='Facilities', data=data_poz)

# %%
sns.relplot(x='Grade', y='Nights_stayed', hue='Facilities', data=data_neg)

# %%
sns.relplot(x='Grade', y='Nights_stayed', hue='Travel_type', data=data_poz)

# %%
sns.relplot(x='Grade', y='Nights_stayed', hue='Room_info', data=data_poz)

# %%
sns.relplot(x='Grade', y='Nights_stayed', hue='Date of stay', data=data_poz)

# %%
sns.distplot(data['Grade'])

# %%
sns.catplot(x='Grade', kind='box', data=data)

# %%
# “strip”, “swarm”, “box”, “violin”, “boxen”, “point”, “bar”, or “count”.
sns.catplot(x='Grade',y='Facilities',hue='Travel_type', data=data_poz)

# %%
# “strip”, “swarm”, “box”, “violin”, “boxen”, “point”, “bar”, or “count”.
sns.catplot(x='Grade',y='Facilities',hue='Travel_type', data=data_poz)

# %%
sns.catplot(x='Nights_stayed',y='Grade',hue='Travel_type',  data=data_poz)

# %%
sns.catplot(x='Nights_stayed',y='Grade',hue='Travel_type', data=data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-8e48d6847072> in <module>
# ----> 1 sns.catplot(x='Nights_stayed',y='Grade',hue='Travel_type', data=data)
#
# ~/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, seed, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3721     # facets to ensure representation of all data in the final plot
#    3722     p = _CategoricalPlotter()
# -> 3723     p.establish_variables(x_, y_, hue, data, orient, order, hue_order)
#    3724     order = p.group_names
#    3725     hue_order = p.hue_names
#
# ~/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     153
#     154             # Figure out the plotting orientation
# --> 155             orient = self.infer_orient(x, y, orient)
#     156
#     157             # Option 2a:
#
# ~/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in infer_orient(self, x, y, orient)
#     352         elif is_not_numeric(y):
#     353             if is_not_numeric(x):
# --> 354                 raise ValueError(no_numeric)
#     355             else:
#     356                 return "h"
#
# ValueError: Neither the `x` nor `y` variable appears to be numeric.
