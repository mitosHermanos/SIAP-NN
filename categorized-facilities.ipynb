# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv("hotels-with-categorized-facilities/country_hall(parsed)(1)_facilities_categorized_facilities.csv")
data.head()
# Out:
#     Guest_country                 Room_info  Nights_stayed Date of stay  \
# 0          Kuwait      Superior Double Room              2  August 2018
# 1          Kuwait      Superior Double Room              2  August 2018
# 2          Kuwait      Superior Double Room              2  August 2018
# 3          Kuwait      Superior Double Room              2  August 2018
# 4  United Kingdom  Penthouse Suite (Family)              1   March 2021
#
#      Travel_type                                             Review  Grade  \
# 0         Family   Everything you needed was there: iron, microw...   10.0
# 1         Family   Everything you needed was there: iron, microw...   10.0
# 2         Family   Everything you needed was there: iron, microw...   10.0
# 3         Family   Everything you needed was there: iron, microw...   10.0
# 4  Solo traveler   Had the penthouse, initially tv didn’t work b...    7.0
#
#                         Title  Positive  Facilities
# ...

# %%
data.tail()
# Out:
#        Guest_country                                  Room_info  \
# 5550  United Kingdom  Superior Double Room with London Eye View
# 5551          Turkey                         Superior Twin Room
# 5552          Turkey                         Superior Twin Room
# 5553          Turkey                         Superior Twin Room
# 5554  United Kingdom  Superior Double Room with London Eye View
#
#       Nights_stayed Date of stay    Travel_type  \
# 5550              2    July 2018         Couple
# 5551              1    July 2018  Solo traveler
# 5552              1    July 2018  Solo traveler
# 5553              1    July 2018  Solo traveler
# 5554              1    July 2018         Family
#
#                                                  Review  Grade      Title  \
# 5550   Customer service\nLack of care\nIncorrect inf...    2.5  Very poo4
# 5551   It was summer 33 degrees outside but the room...    6.7   Pleasant
# ...

# %%
data.shape
# Out:
# (5555, 10)

# %%
data.nunique()
# Out:
# Guest_country      92
# Room_info          13
# Nights_stayed      13
# Date of stay       30
# Travel_type         4
# Review           2456
# Grade              32
# Title             893
# Positive            2
# Facilities         16
# dtype: int64

# %%
data.isnull().sum()
data_poz = data[data['Positive'] > 0]
data_neg = data[data['Positive'] < 1]

# %%
# analiza zavisnosti podataka

# %%
corelation = data.corr()
sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.columns, annot=True)

# %%
sns.pairplot(data)

# %%
sns.relplot(x='Grade', y='Nights_stayed', hue='Facilities', data=data_poz)

# %%
sns.relplot(x='Grade', y='Nights_stayed', hue='Facilities', data=data_neg)

# %%
sns.relplot(x='Grade', y='Nights_stayed', hue='Travel_type', data=data_poz)

# %%
sns.relplot(x='Grade', y='Nights_stayed', hue='Room_info', data=data_poz)

# %%
sns.relplot(x='Grade', y='Nights_stayed', hue='Date of stay', data=data_poz)

# %%
sns.distplot(data['Grade'])

# %%
sns.catplot(x='Grade', kind='box', data=data)

# %%
# “strip”, “swarm”, “box”, “violin”, “boxen”, “point”, “bar”, or “count”.
sns.catplot(x='Grade',y='Facilities',hue='Travel_type', data=data_poz)

# %%
sns.catplot(x='Grade',y='Facilities',hue='Travel_type', data=data_neg)

# %%
sns.catplot(x='Nights_stayed',y='Grade',hue='Travel_type', data=data_poz)

# %%
sns.catplot(x='Nights_stayed',y='Grade',hue='Travel_type', data=data_neg)
